# %%
from pathlib import Path

# %%
base = Path(r'C:\Users\Erick J. Sarante\OneDrive - Universidade da Coruña\Master en Tecnicas estadisticas\Notebooks\SF_Rent_Analisis')

# %%
(base / 'analysis' ).mkdir(exist_ok=True, parents=True)
(base / 'data' / 'processed' ).mkdir(exist_ok=True, parents=True)
(base / 'data' / 'processed' / '.gitkeep').touch(exist_ok=True)
(base / 'data' / 'raw' ).mkdir(exist_ok=True, parents=True)
(base / 'scr' ).mkdir(exist_ok=True, parents=True)

# %%
(base / '.gitignore').touch(exist_ok=True)
(base / 'README.md').touch(exist_ok=True)
(base / 'requeriment.txt').touch(exist_ok=True)
